# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# Import the numpy and pandas package

import numpy as np
import pandas as pd

# Data Visualisation

import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Load Data

# %%
wine_data =pd.read_csv("redwine.csv")

# %%
wine_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_data.shape
# Out:
# (1599, 12)

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # Data cleaning

# %%
sns.heatmap(wine_data)

# %%
wine_data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
wine_data.duplicated().sum()
# Out:
# 240

# %%
wine_data.drop_duplicates(keep = 'first', inplace = True)
wine_data.duplicated().sum()
# Out:
# 0

# %%
wine_data['total sulfur dioxide'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Data Visualization

# %%
#redwine quality range and their count 
wine_data['quality'].hist(color= "green",figsize = (6,5))

# %%
#Analysis of 'quality' with respect  to other features 

plt.figure(figsize=(15,15))
plt.subplot(4,3,1)
sns.barplot(x ='quality', y='fixed acidity', data = wine_data,palette = "winter")
plt.subplot(4,3,2)
sns.barplot(x ='quality', y='volatile acidity', data = wine_data,palette = "winter")
plt.subplot(4,3,3)
sns.barplot(x ='quality', y='citric acid', data = wine_data,palette = "winter")
plt.subplot(4,3,4)
sns.barplot(x ='quality', y='residual sugar', data = wine_data,palette = "winter")
plt.subplot(4,3,5)
sns.barplot(x ='quality', y='chlorides', data = wine_data,palette = "winter")
plt.subplot(4,3,6)
sns.barplot(x ='quality', y='free sulfur dioxide', data =wine_data,palette = "winter")
plt.subplot(4,3,7)
sns.barplot(x ='quality', y='total sulfur dioxide', data = wine_data,palette = "winter")
plt.subplot(4,3,8)
sns.barplot(x ='quality', y='density', data = wine_data,palette = "winter")
plt.subplot(4,3,9)
sns.barplot(x ='quality', y='pH', data = wine_data,palette = "winter")
plt.subplot(4,3,10)
sns.barplot(x ='quality', y='sulphates', data = wine_data,palette = "winter")
plt.subplot(4,3,11)
sns.barplot(x ='quality', y='alcohol', data = wine_data,palette = "winter")

# %%
#heatmeap
plt.figure(figsize=(10,10))
sns.heatmap(wine_data.corr(), annot = True, cmap = 'Blues', fmt = '.1f')

# %%
sns.distplot(wine_data['alcohol'])

# %%
#lets visualize whole data
sns.pairplot(wine_data)

# %% [markdown]
# # Feature selection

# %%
# Create Classification version of target variable
wine_data['goodquality'] = [1 if x >= 7 else 0 for x in wine_data['quality']]
wine_data['goodquality'].value_counts()
# Out:
# 0    1175
# 1     184
# Name: goodquality, dtype: int64

# %% [markdown]
# # Data preprocessing and model training

# %%
# Separate feature variables and target variable
X = wine_data.drop(['quality','goodquality'], axis = 1)
y = wine_data['goodquality']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
print(y.shape, y_train.shape, y_test.shape)
# Out:
# (1359, 11) (1087, 11) (272, 11)
# (1359,) (1087,) (272,)

# %% [markdown]
# # Model1:  Logistic regression

# %%
#logistic regression
lmodel = LogisticRegression()
lmodel.fit(X_train,y_train)

y_pred = lmodel.predict(X_test)

# %%
print("Accuracy Score:",accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy Score: 90.44117647058823

# %%
confusion_mat = confusion_matrix(y_test,y_pred)
print(confusion_mat)
print(classification_report(y_test,y_pred))
# Out:
# [[229  10]
#  [ 16  17]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       239
#            1       0.63      0.52      0.57        33
#
#     accuracy                           0.90       272
#    macro avg       0.78      0.74      0.76       272
# weighted avg       0.90      0.90      0.90       272

# %% [markdown]
# # Model2: Random Forest classifier

# %%
#random forest classifier
rfc_model = RandomForestClassifier()
rfc_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#accuracy score
data_prediction = rfc_model.predict(X_test)
print('Accuracy Score: ', accuracy_score(y_test, data_prediction)*100)
# Out:
# Accuracy Score:  87.5

# %%
confusion_mat = confusion_matrix(y_test,data_prediction)
print(confusion_mat)
# Out:
# [[223  16]
#  [ 18  15]]

# %%
# Logistic regression is having better accuracy score then random forest classifier for given data

# %% [markdown]
# # Predictive system

# %%
input_data = input("Enter values as(fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,quality):")
list  = input_data.split(",")
#changing the input data to a numpy array
input_data_as_numpy_array = np.asarray(list)
print(input_data_as_numpy_array) 
#reshapr the data
reshaped_data = input_data_as_numpy_array.reshape(1,-1)
#debug
print(reshaped_data)

prediction = rfc_model.predict(reshaped_data)
print(prediction)

if (prediction) == 1:
    print("It's a Good quality Wine")
else:
    print("It's a Bad quality Wine")
# Out:
# Enter values as(fixed acidity,volatile acidity,citric acid,residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide,density,pH,sulphates,alcohol,quality):7.3,0.65,0.0,1.2,0.065,15.0,21.0,0.9946,3.39,0.47,10.0
# ['7.3' '0.65' '0.0' '1.2' '0.065' '15.0' '21.0' '0.9946' '3.39' '0.47'
#  '10.0']
# [['7.3' '0.65' '0.0' '1.2' '0.065' '15.0' '21.0' '0.9946' '3.39' '0.47'
#   '10.0']]
# [1]
# It's a Good quality Wine

# %%
#correct output
